# %% [markdown]
# # 🤖 Divvy Bike Usage Prediction - Model Training & Evaluation
#
# **Project:** Prédiction de l'utilisation des vélos Divvy à Chicago
# **Author:** Noé
# **Date:** 2026-01-14
# **Objective:** Entraîner 3 modèles ML et sélectionner le meilleur
#
# ---
#
# ## 🎯 Objectif
#
# **Prédire le nombre de trajets PAR HEURE** pour optimiser la disponibilité des vélos
#
# ### 🏆 Modèles à comparer:
# 1. **Linear Regression** - Baseline simple et explicable
# 2. **Random Forest** - Capture les interactions non-linéaires
# 3. **XGBoost** - État de l'art pour les données tabulaires
#
# ### 📊 Métriques d'évaluation:
# - **RMSE** (Root Mean Squared Error)
# - **MAE** (Mean Absolute Error)
# - **R²** (Coefficient de détermination) - Objectif ≥ 0.75
# - **MAPE** (Mean Absolute Percentage Error) - Objectif ≤ 20%
#
# ---

# %% [markdown]
# ## 1. Setup & Data Loading 📊

# %%
# Import des bibliothèques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
from pathlib import Path
import joblib

# Machine Learning
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
import xgboost as xgb

# Configuration
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
np.random.seed(42)

print("✅ Bibliothèques chargées!")
# Out:
# ✅ Bibliothèques chargées!

# %%
# Chemins
DATA_PATH = Path('../data')
PROCESSED_PATH = DATA_PATH / 'processed'
MODELS_PATH = Path('../models')
MODELS_PATH.mkdir(exist_ok=True)

print(f"📁 Paths configurés")
# Out:
# 📁 Paths configurés

# %% [markdown]
# ### 1.1 Charger les datasets

# %%
# Charger train et test
print("📂 Chargement des datasets...")
df_train = pd.read_csv(PROCESSED_PATH / 'train_2024_hourly.csv')
df_test = pd.read_csv(PROCESSED_PATH / 'test_2025_hourly.csv')

print(f"\n✅ Datasets chargés:")
print(f"   Train 2024: {df_train.shape}")
print(f"   Test 2025:  {df_test.shape}")

df_train.head()
df_test.head()
# Out:
# 📂 Chargement des datasets...
#
# ✅ Datasets chargés:
#    Train 2024: (8782, 14)
#    Test 2025:  (8758, 14)
#          datetime_hour  trip_count  hour  day_of_week  month  is_weekend  \
# 0  2025-01-01 00:00:00         336     0            2      1           0
# 1  2025-01-01 01:00:00         436     1            2      1           0
# 2  2025-01-01 02:00:00         213     2            2      1           0
# 3  2025-01-01 03:00:00          57     3            2      1           0
# 4  2025-01-01 04:00:00          24     4            2      1           0
#
#    temperature  precipitation  wind_speed  is_holiday  season_fall  \
# 0         -1.5            0.0        21.0           1        False
# 1         -1.5            0.0        21.0           1        False
# 2         -1.5            0.0        21.0           1        False
# 3         -1.5            0.0        21.0           1        False
# 4         -1.5            0.0        21.0           1        False
#
#    season_spring  season_summer  season_winter
# 0          False          False           True
# 1          False          False           True
# 2          False          False           True
# 3          False          False           True
# 4          False          False           True

# %% [markdown]
# ### 1.2 Préparer X et y

# %%
# Séparer features et target
X_train = df_train.drop(['datetime_hour', 'trip_count'], axis=1)
y_train = df_train['trip_count']

X_test = df_test.drop(['datetime_hour', 'trip_count'], axis=1)
y_test = df_test['trip_count']

print(f"✅ Données préparées:")
print(f"   X_train: {X_train.shape}")
print(f"   y_train: {y_train.shape}")
print(f"\nFeatures: {X_train.columns.tolist()}")
# Out:
# ✅ Données préparées:
#    X_train: (8782, 12)
#    y_train: (8782,)
#
# Features: ['hour', 'day_of_week', 'month', 'is_weekend', 'temperature', 'precipitation', 'wind_speed', 'is_holiday', 'season_fall', 'season_spring', 'season_summer', 'season_winter']

# %% [markdown]
# ### 1.3 Gérer les valeurs manquantes

# %%
# Vérifier les colonnes
print(f"Colonnes Train ({len(X_train.columns)}): {X_train.columns.tolist()}")
print(f"Colonnes Test ({len(X_test.columns)}): {X_test.columns.tolist()}")

# Aligner les colonnes (garder seulement les colonnes communes)
common_cols = X_train.columns.intersection(X_test.columns).tolist()
print(f"\nColonnes communes ({len(common_cols)}): {common_cols}")

X_train = X_train[common_cols]
X_test = X_test[common_cols]

print(f"\nNaN avant imputation - Train: {X_train.isnull().sum().sum()}, Test: {X_test.isnull().sum().sum()}")

# Imputer avec la médiane
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
X_train = pd.DataFrame(
    imputer.fit_transform(X_train),
    columns=common_cols,
    index=X_train.index
)
X_test = pd.DataFrame(
    imputer.fit_transform(X_test),
    columns=common_cols,
    index=X_test.index
)

print(f"NaN après imputation - Train: {X_train.isnull().sum().sum()}, Test: {X_test.isnull().sum().sum()}")
print(f"\n✅ Données alignées et nettoyées: {X_train.shape}")
# Out:
# Colonnes Train (12): ['hour', 'day_of_week', 'month', 'is_weekend', 'temperature', 'precipitation', 'wind_speed', 'is_holiday', 'season_fall', 'season_spring', 'season_summer', 'season_winter']
# Colonnes Test (12): ['hour', 'day_of_week', 'month', 'is_weekend', 'temperature', 'precipitation', 'wind_speed', 'is_holiday', 'season_fall', 'season_spring', 'season_summer', 'season_winter']
#
# Colonnes communes (12): ['hour', 'day_of_week', 'month', 'is_weekend', 'temperature', 'precipitation', 'wind_speed', 'is_holiday', 'season_fall', 'season_spring', 'season_summer', 'season_winter']
#
# NaN avant imputation - Train: 0, Test: 0
# NaN après imputation - Train: 0, Test: 0
#
# ✅ Données alignées et nettoyées: (8782, 12)

# %% [markdown]
# ---
#
# ## 2. Model 1: Linear Regression 📈

# %%
# Standardiser
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Entraîner
print("🏋️ Entraînement Linear Regression...")
lr_model = LinearRegression()
lr_model.fit(X_train_scaled, y_train)

# Prédire
y_train_pred_lr = lr_model.predict(X_train_scaled)
y_test_pred_lr = lr_model.predict(X_test_scaled)

print("✅ Linear Regression terminé!")
# Out:
# 🏋️ Entraînement Linear Regression...
# ✅ Linear Regression terminé!

# %%
# Fonction d'évaluation
def evaluate_model(y_true, y_pred, name="Model"):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    print(f"\n{name}:")
    print(f"  RMSE: {rmse:.2f}")
    print(f"  MAE:  {mae:.2f}")
    print(f"  R²:   {r2:.4f}")
    print(f"  MAPE: {mape:.2f}%")
    
    return {'RMSE': rmse, 'MAE': mae, 'R2': r2, 'MAPE': mape}

# Évaluer Linear Regression
print("="*60)
print("LINEAR REGRESSION")
print("="*60)
lr_train = evaluate_model(y_train, y_train_pred_lr, "Train")
lr_test = evaluate_model(y_test, y_test_pred_lr, "Test")
# Out:
# ============================================================
# LINEAR REGRESSION
# ============================================================
#
# Train:
#   RMSE: 530.85
#   MAE:  400.30
#   R²:   0.3681
#   MAPE: 300.10%
#
# Test:
#   RMSE: 506.77
#   MAE:  382.62
#   R²:   0.3858
#   MAPE: 313.23%

# %% [markdown]
# ---
#
# ## 3. Model 2: Random Forest 🌲

# %%
# Entraîner Random Forest
print("🏋️ Entraînement Random Forest...")
rf_model = RandomForestRegressor(
    n_estimators=100,
    max_depth=15,
    min_samples_split=5,
    random_state=42,
    n_jobs=-1,
    verbose=1
)
rf_model.fit(X_train, y_train)

# Prédire
y_train_pred_rf = rf_model.predict(X_train)
y_test_pred_rf = rf_model.predict(X_test)

print("\n✅ Random Forest terminé!")
# Out:
# 🏋️ Entraînement Random Forest...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 14 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=14)]: Using backend ThreadingBackend with 14 concurrent workers.
# [Parallel(n_jobs=14)]: Done  22 tasks      | elapsed:    0.0s
# ✅ Random Forest terminé!
# [Parallel(n_jobs=14)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=14)]: Using backend ThreadingBackend with 14 concurrent workers.
# [Parallel(n_jobs=14)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=14)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
# Évaluer Random Forest
print("="*60)
print("RANDOM FOREST")
print("="*60)
rf_train = evaluate_model(y_train, y_train_pred_rf, "Train")
rf_test = evaluate_model(y_test, y_test_pred_rf, "Test")
# Out:
# ============================================================
# RANDOM FOREST
# ============================================================
#
# Train:
#   RMSE: 84.23
#   MAE:  49.98
#   R²:   0.9841
#   MAPE: 14.54%
#
# Test:
#   RMSE: 205.07
#   MAE:  122.15
#   R²:   0.8994
#   MAPE: 34.49%

# %%
# Feature importance
rf_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': rf_model.feature_importances_
}).sort_values('importance', ascending=False)

print("\n🔧 Feature Importance:")
print(rf_importance)

fig = px.bar(rf_importance, x='importance', y='feature', orientation='h',
             title='Random Forest - Feature Importance')
fig.show()
# Out:
# 🔧 Feature Importance:
#           feature  importance
# 0            hour    0.534208
# 4     temperature    0.329756
# 1     day_of_week    0.046657
# 6      wind_speed    0.035968
# 3      is_weekend    0.019012
# 2           month    0.015989
# 8     season_fall    0.006642
# 7      is_holiday    0.005089
# 10  season_summer    0.002735
# 9   season_spring    0.001653
# 5   precipitation    0.001442
# 11  season_winter    0.000849

# %% [markdown]
# ---
#
# ## 4. Model 3: XGBoost 🚀

# %%
# Entraîner XGBoost
print("🏋️ Entraînement XGBoost...")
xgb_model = xgb.XGBRegressor(
    n_estimators=200,
    max_depth=8,
    learning_rate=0.1,
    subsample=0.8,
    random_state=42,
    n_jobs=-1
)
xgb_model.fit(X_train, y_train)

# Prédire
y_train_pred_xgb = xgb_model.predict(X_train)
y_test_pred_xgb = xgb_model.predict(X_test)

print("\n✅ XGBoost terminé!")
# Out:
# 🏋️ Entraînement XGBoost...
#
# ✅ XGBoost terminé!

# %%
# Évaluer XGBoost
print("="*60)
print("XGBOOST")
print("="*60)
xgb_train = evaluate_model(y_train, y_train_pred_xgb, "Train")
xgb_test = evaluate_model(y_test, y_test_pred_xgb, "Test")
# Out:
# ============================================================
# XGBOOST
# ============================================================
#
# Train:
#   RMSE: 38.33
#   MAE:  25.42
#   R²:   0.9967
#   MAPE: 11.01%
#
# Test:
#   RMSE: 207.71
#   MAE:  123.01
#   R²:   0.8968
#   MAPE: 35.72%

# %% [markdown]
# ---
#
# ## 5. Comparaison des Modèles 🏆

# %%
# Tableau comparatif
comparison = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest', 'XGBoost'],
    'Test_R2': [lr_test['R2'], rf_test['R2'], xgb_test['R2']],
    'Test_MAPE': [lr_test['MAPE'], rf_test['MAPE'], xgb_test['MAPE']],
    'Test_RMSE': [lr_test['RMSE'], rf_test['RMSE'], xgb_test['RMSE']],
    'Test_MAE': [lr_test['MAE'], rf_test['MAE'], xgb_test['MAE']]
})

print("="*80)
print("COMPARAISON DES MODÈLES")
print("="*80)
print(comparison.to_string(index=False))

# Meilleur modèle
best_idx = comparison['Test_R2'].idxmax()
best_model = comparison.loc[best_idx, 'Model']
best_r2 = comparison.loc[best_idx, 'Test_R2']
best_mape = comparison.loc[best_idx, 'Test_MAPE']

print(f"\n🏆 Meilleur modèle: {best_model}")
print(f"   R²: {best_r2:.4f}")
print(f"   MAPE: {best_mape:.2f}%")
# Out:
# ================================================================================
# COMPARAISON DES MODÈLES
# ================================================================================
#             Model  Test_R2  Test_MAPE  Test_RMSE   Test_MAE
# Linear Regression 0.385802 313.232525 506.774456 382.619940
#     Random Forest 0.899431  34.494014 205.065062 122.149323
#           XGBoost 0.896823  35.722604 207.707379 123.010063
#
# 🏆 Meilleur modèle: Random Forest
#    R²: 0.8994
#    MAPE: 34.49%

# %%
# Visualisation comparative
fig = make_subplots(rows=1, cols=2, subplot_titles=('R² Score', 'MAPE %'))

fig.add_trace(go.Bar(x=comparison['Model'], y=comparison['Test_R2'], 
                     marker_color='steelblue'), row=1, col=1)
fig.add_trace(go.Bar(x=comparison['Model'], y=comparison['Test_MAPE'], 
                     marker_color='coral'), row=1, col=2)

fig.add_hline(y=0.75, line_dash="dash", line_color="green", 
              annotation_text="Objectif", row=1, col=1)
fig.add_hline(y=20, line_dash="dash", line_color="red", 
              annotation_text="Objectif", row=1, col=2)

fig.update_layout(title="Comparaison des Modèles", height=500, showlegend=False)
fig.show()

# %% [markdown]
# ---
#
# ## 6. Visualisation des Prédictions 📊

# %%
# Prendre le meilleur modèle
if best_model == 'Linear Regression':
    best_pred = y_test_pred_lr
elif best_model == 'Random Forest':
    best_pred = y_test_pred_rf
else:
    best_pred = y_test_pred_xgb

# Predictions vs Actual
fig = go.Figure()
fig.add_trace(go.Scatter(x=y_test, y=best_pred, mode='markers',
                         marker=dict(size=3, opacity=0.5)))
fig.add_trace(go.Scatter(x=[0, y_test.max()], y=[0, y_test.max()],
                         mode='lines', line=dict(color='red', dash='dash')))
fig.update_layout(title=f'{best_model} - Predictions vs Actual',
                  xaxis_title='Actual', yaxis_title='Predicted', height=500)
fig.show()

# %%
# Timeline (première semaine)
sample = slice(0, 168)
fig = go.Figure()
fig.add_trace(go.Scatter(y=y_test.iloc[sample].values, name='Actual',
                         line=dict(color='steelblue')))
fig.add_trace(go.Scatter(y=best_pred[sample], name='Predicted',
                         line=dict(color='coral', dash='dash')))
fig.update_layout(title='Timeline - Première semaine 2025',
                  xaxis_title='Heures', yaxis_title='Trip Count', height=500)
fig.show()

# %% [markdown]
# ---
#
# ## 7. Sauvegarder les Modèles 💾

# %%
# Sauvegarder tous les modèles
joblib.dump(lr_model, MODELS_PATH / 'linear_regression.pkl')
joblib.dump(scaler, MODELS_PATH / 'scaler.pkl')
joblib.dump(rf_model, MODELS_PATH / 'random_forest.pkl')
joblib.dump(xgb_model, MODELS_PATH / 'xgboost.pkl')

# Sauvegarder le meilleur
if best_model == 'Linear Regression':
    joblib.dump(lr_model, MODELS_PATH / 'best_model.pkl')
elif best_model == 'Random Forest':
    joblib.dump(rf_model, MODELS_PATH / 'best_model.pkl')
else:
    joblib.dump(xgb_model, MODELS_PATH / 'best_model.pkl')

comparison.to_csv(MODELS_PATH / 'model_comparison.csv', index=False)

print("✅ Tous les modèles sauvegardés!")
print(f"   Meilleur: {best_model}")
# Out:
# ✅ Tous les modèles sauvegardés!
#    Meilleur: Random Forest

# %% [markdown]
# ---
#
# ## 🎉 Modeling Terminé!
#
# **Status:** ✅ Completed
# **Next:** Rapport académique
#
# ---
